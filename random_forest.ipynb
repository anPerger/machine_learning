i_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# 5           -0.229     0.972          0.315         -0.105  296.28613
# 6           -0.028     0.848          0.033         -0.072  286.99948
# 7           -0.024     0.964          0.038         -0.038  286.80847
# 8           -0.027     1.952          0.099         -0.110  292.24728
# 9           -0.045     1.451          0.110         -0.110  281.28812
# 10          -0.114     1.022          0.143         -0.107  295.64871
# 11          -0.176     0.848          0.224         -0.075  297.07993
# 12          -0.208     0.947          0.308         -0.096  295.81454
# 13          -0.072     0.786          0.088         -0.088  297.15442
# 14          -0.035     0.696          0.056         -0.068  288.13824
# 15          -0.056     0.672          0.062         -0.036  283.71088
# 16          -0.060     0.819          0.067         -0.082  283.76547
# 17          -0.045     0.910          0.057         -0.086  292.37613
# 18          -0.014     1.580          0.064         -0.064  292.27374
# 19          -0.020     0.828          0.032         -0.065  290.46512
# 20          -0.136     0.847          0.161         -0.069  297.80826
# 21          -0.168     0.831          0.207         -0.069  294.26581
# 22          -0.160     0.831          0.186         -0.080  295.66522
# 23          -0.120     0.983          0.148         -0.049  296.69861
# 24          -0.217     1.091          0.350         -0.150  283.72592
# 25          -0.028     0.848          0.033         -0.072  286.99948
# 26          -0.028     0.848          0.033         -0.072  286.99948
# 27          -0.150     0.798          0.181         -0.077  285.71854
# 28          -0.150     0.798          0.181         -0.077  285.71854
# 30          -0.169     0.910          0.228         -0.105  297.92365
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# 5   48.224670      15.714
# 6   48.375790      15.841
# 7   49.316399      11.338
# 8   47.969521      10.463
# 9   42.451080      13.563
# 10  48.495560      12.772
# 11  47.597401      15.472
# 12  47.690350      15.341
# 13  47.668701      15.788
# 14  47.724449      15.302
# 15  47.863270      15.784
# 16  47.804298      15.269
# 17  47.880989      15.416
# 18  37.671558      12.394
# 19  47.929180      15.377
# 20  47.946671      15.861
# 21  49.314091      15.356
# 22  49.351009      15.525
# 23  49.316479      15.207
# 24  49.479519      15.250
# 25  48.375790      15.841
# 26  48.375790      15.841
# 27  48.505859      15.082
# 28  48.505859      15.082
# 30  48.777321      15.540
#
# [30 rows x 41 columns]

# %%
X = no_candidates_df.drop(columns=["koi_disposition"])
y = no_candidates_df["koi_disposition"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9826546003016591

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=700)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9796380090497737

# %%
sorted(zip(rf.feature_importances_, X), reverse=True)
# Out:
# [(0.12969249094252375, 'koi_fpflag_co'),
#  (0.08613276537156728, 'koi_steff_err1'),
#  (0.06871047294449321, 'koi_prad'),
#  (0.06762643255100768, 'koi_steff_err2'),
#  (0.06645238147787429, 'koi_fpflag_ss'),
#  (0.061029682620724966, 'koi_fpflag_nt'),
#  (0.046087334761540706, 'koi_prad_err2'),
#  (0.04560962034714434, 'koi_prad_err1'),
#  (0.04183865148772331, 'koi_duration_err1'),
#  (0.040385542557464946, 'koi_duration_err2'),
#  (0.029304482186402938, 'koi_fpflag_ec'),
#  (0.023049450119586236, 'koi_model_snr'),
#  (0.021418303580641018, 'koi_insol_err1'),
#  (0.021268130217588856, 'koi_time0bk_err1'),
#  (0.01989542388517608, 'koi_period'),
#  (0.019272097607269608, 'koi_time0bk_err2'),
#  (0.01841573450350422, 'koi_teq'),
#  (0.01628804361280283, 'koi_insol'),
#  (0.01626948042680377, 'koi_srad_err1'),
#  (0.015698121817687028, 'koi_insol_err2'),
#  (0.01461006583969441, 'koi_depth'),
#  (0.013700856909760967, 'koi_impact'),
#  (0.012710136040770722, 'koi_period_err2'),
#  (0.011245060723133596, 'koi_period_err1'),
#  (0.01109300675699983, 'koi_depth_err2'),
#  (0.010230725750393084, 'koi_depth_err1'),
#  (0.009898866763296899, 'koi_slogg_err2'),
#  (0.007248164567790993, 'koi_duration'),
#  (0.007091753540972156, 'koi_time0bk'),
#  (0.006298685998025082, 'koi_srad'),
#  (0.0051189348188530655, 'koi_slogg'),
#  (0.005008432160368119, 'ra'),
#  (0.004861490683809068, 'koi_impact_err1'),
#  (0.004802902178895353, 'koi_kepmag'),
#  (0.004560973651103776, 'koi_srad_err2'),
#  (0.004082320082246543, 'koi_steff'),
#  (0.0037207882412542007, 'koi_impact_err2'),
#  (0.003563050108205295, 'dec'),
#  (0.003474942344872721, 'koi_slogg_err1'),
#  (0.0022341998200271617, 'koi_tce_plnt_num')]

# %%
limited_features = no_candidates_df[['koi_fpflag_co', 'koi_steff_err1', 'koi_prad', 'koi_steff_err2', 'koi_fpflag_ss', 
                                     'koi_fpflag_nt', 'koi_prad_err2', 'koi_duration_err2', 'koi_prad_err1',
                                     'koi_duration_err1', 'koi_fpflag_ec', 'koi_insol_err1', 'koi_time0bk_err2',
                                     'koi_period', 'koi_model_snr']]
limited_features
# Out:
#       koi_fpflag_co  koi_steff_err1  koi_prad  koi_steff_err2  koi_fpflag_ss  \
# 0                 0              81      2.83             -81              0
# 1                 0             158     14.60            -176              1
# 2                 0             157     33.46            -174              1
# 3                 0             169      2.75            -211              0
# 4                 0             189      2.77            -232              0
# ...             ...             ...       ...             ...            ...
# 6983              0             128    534.47            -141              1
# 6986              0             169      1.11            -152              0
# 6987              1             139     29.35            -166              1
# 6989              1             193      1.07            -236              0
# 6990              1             158      1.05            -225              0
#
#       koi_fpflag_nt  koi_prad_err2  koi_duration_err2  koi_prad_err1  \
# 0                 0          -0.19           -0.11600           0.32
# 1                 0          -1.31           -0.03410           3.92
# 2                 0          -2.83           -0.00537           8.50
# 3                 0          -0.35           -0.04200           0.88
# 4                 0          -0.30           -0.06730           0.90
# ...             ...            ...                ...            ...
# 6983              0        -131.00           -0.89900         107.10
# 6986              0          -0.23           -0.63400           0.32
# 6987              0          -2.57           -0.01740           7.70
# 6989              0          -0.11           -0.16200           0.36
# 6990              0          -0.12           -0.28300           0.36
#
#       koi_duration_err1  koi_fpflag_ec  koi_insol_err1  koi_time0bk_err2  \
# 0               0.11600              0            2.87         -0.003520
# 1               0.03410              0           31.04         -0.000581
# 2               0.00537              0          668.95         -0.000115
# 3               0.04200              0          874.33         -0.001130
# 4               0.06730              0          420.33         -0.001900
# ...                 ...            ...             ...               ...
# 6983            0.89900              0          143.48         -0.012200
# 6986            0.63400              1          152.77         -0.015700
# 6987            0.01740              0         3406.38         -0.000170
# 6989            0.16200              0         5675.74         -0.002850
# 6990            0.28300              1          600.39         -0.010800
#
#       koi_period  koi_model_snr
# 0      54.418383           25.8
# 1      19.899140           76.3
# 2       1.736952          505.6
# 3       2.525592           40.9
# 4       4.134435           40.2
# ...          ...            ...
# 6983   21.513523          171.5
# 6986    8.589871            8.4
# 6987    0.527699          453.3
# 6989    0.681402           12.3
# 6990    4.856035            8.2
#
# [5304 rows x 15 columns]

# %%
X = limited_features
y = no_candidates_df["koi_disposition"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9826546003016591

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=700)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9819004524886877

# %%
sorted(zip(rf.feature_importances_, X), reverse=True)
# Out:
# [(0.14984931157213913, 'koi_fpflag_co'),
#  (0.10192343586998248, 'koi_steff_err1'),
#  (0.08763521146876019, 'koi_prad'),
#  (0.0846961034450453, 'koi_steff_err2'),
#  (0.08210951238585391, 'koi_fpflag_nt'),
#  (0.08060142905831325, 'koi_fpflag_ss'),
#  (0.05879174720047007, 'koi_duration_err2'),
#  (0.056365653701092394, 'koi_prad_err1'),
#  (0.05581011517407524, 'koi_prad_err2'),
#  (0.05526361689907847, 'koi_duration_err1'),
#  (0.0422168057802521, 'koi_period'),
#  (0.04164032672594257, 'koi_insol_err1'),
#  (0.04115281779987409, 'koi_fpflag_ec'),
#  (0.03123450135070218, 'koi_model_snr'),
#  (0.030709411568418693, 'koi_time0bk_err2')]

# %%
more_limited_features = no_candidates_df[['koi_fpflag_co', 'koi_steff_err1', 'koi_prad', 'koi_steff_err2', 'koi_fpflag_ss']]
more_limited_features
# Out:
#       koi_fpflag_co  koi_steff_err1  koi_prad  koi_steff_err2  koi_fpflag_ss
# 0                 0              81      2.83             -81              0
# 1                 0             158     14.60            -176              1
# 2                 0             157     33.46            -174              1
# 3                 0             169      2.75            -211              0
# 4                 0             189      2.77            -232              0
# ...             ...             ...       ...             ...            ...
# 6983              0             128    534.47            -141              1
# 6986              0             169      1.11            -152              0
# 6987              1             139     29.35            -166              1
# 6989              1             193      1.07            -236              0
# 6990              1             158      1.05            -225              0
#
# [5304 rows x 5 columns]

# %%
X = more_limited_features
y = no_candidates_df["koi_disposition"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8725490196078431

# %%
rf = RandomForestClassifier(n_estimators=700)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8981900452488688
